# %%
import pandas as pd
import numpy as np 
import os
import glob
from nilearn import plotting

# %%
os.chdir('../anats')
home = os.getcwd()

# %%
extracted = glob.glob('*brain.nii.gz')

# %%
for i in extracted:
    plotting.plot_anat(f'/data/projects/srndna-structure/anats/{i}')
# Out:
# /home/local/TU/tul67061/anaconda3/lib/python3.7/site-packages/nilearn/plotting/displays.py:591: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   facecolor=facecolor)
# /home/local/TU/tul67061/anaconda3/lib/python3.7/site-packages/nilearn/plotting/displays.py:591: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   facecolor=facecolor)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-2ddfb76de89c> in <module>
# ...

# %%
# !fsl
# Out:
# /usr/share/fsl/5.0/bin/fast -t 1 -n 3 -H 0.1 -I 4 -l 20.0 -b -o /data/projects/srndna-structure/anats/sub-104_desc-preproc_T1w_brain /data/projects/srndna-structure/anats/sub-104_desc-preproc_T1w_brain
# /usr/share/fsl/5.0/bin/fast: error while loading shared libraries: libnewimage.so: cannot open shared object file: No such file or directory
#
# FATAL ERROR ENCOUNTERED:
# COMMAND:
# /usr/share/fsl/5.0/bin/fast -t 1 -n 3 -H 0.1 -I 4 -l 20.0 -b -o /data/projects/srndna-structure/anats/sub-104_desc-preproc_T1w_brain /data/projects/srndna-structure/anats/sub-104_desc-preproc_T1w_brain
# ERROR MESSAGE:
# /usr/share/fsl/5.0/bin/fast: error while loading shared libraries: libnewimage.so: cannot open shared object file: No such file or directory
# END OF ERROR MESSAGE
